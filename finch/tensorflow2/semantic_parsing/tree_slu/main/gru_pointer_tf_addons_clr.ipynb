# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/semantic_parsing/tree_slu/main')

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
from tensorflow_addons.optimizers.cyclical_learning_rate import Triangular2CyclicalLearningRate
from modified_beam_search_decoder import BeamSearchDecoder

import tensorflow as tf
import tensorflow_addons as tfa

import numpy as np
import pprint
import logging
import time
import nltk

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0
# WARNING:tensorflow:From <ipython-input-3-cc796b6e5db2>:14: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
# stream data from text files
def data_generator(f_path, params):
  with open(f_path) as f:
    print('Reading', f_path)
    for line in f:
      text_raw, text_tokenized, label = line.split('\t')
      text_tokenized = text_tokenized.lower().split()
      label = label.replace('[', '[ ').lower().split()
      source = [params['tgt2idx'].get(w, len(params['tgt2idx'])) for w in text_tokenized]
      target = [params['tgt2idx'].get(w, len(params['tgt2idx'])) for w in label]
      target_in = [1] + target
      target_out = target + [2]
      yield (source, target_in, target_out)

# %%
def dataset(is_training, params):
  _shapes = ([None], [None], [None])
  _types = (tf.int32, tf.int32, tf.int32)
  _pads = (0, 0, 0)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['train_batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['eval_batch_size'], _shapes, _pads)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
  return ds

# %%
class Embed(tf.keras.Model):
  def __init__(self):
    super().__init__()
    self.embedding = tf.Variable(np.load('../vocab/word.npy'),
                                 dtype=tf.float32,
                                 name='pretrained_embedding')
  
  def call(self, inputs):
    if inputs.dtype != tf.int32:
      inputs = tf.cast(inputs, tf.int32)
    x = tf.nn.embedding_lookup(self.embedding, inputs)
    return x

# %%
class Encoder(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.bilstm = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(
      params['rnn_units'], return_state=True, return_sequences=True, zero_output_for_mask=True))
    self.state_fc = tf.keras.layers.Dense(params['rnn_units'], params['activation'], name='state_fc')
  
  def call(self, inputs, mask, training):
    if mask.dtype != tf.bool:
      mask = tf.cast(mask, tf.bool)
    x = self.dropout(inputs, training=training)
    
    encoder_o, state_fw, state_bw = self.bilstm(x, mask=mask)
    encoder_s = self.state_fc(tf.concat((state_fw, state_bw), -1))
    
    return encoder_o, tuple([encoder_s])

# %%
class TiedDense(tf.keras.layers.Layer):
  def __init__(self, tied_embed, out_dim):
    super().__init__()
    self.tied_embed = tied_embed
    self.out_dim = out_dim
  
  def build(self, input_shape):
    self.bias = self.add_weight(name='bias',
                                shape=[self.out_dim],
                                trainable=True)
    super().build(input_shape)
  
  def call(self, inputs):
    x = tf.matmul(inputs, self.tied_embed, transpose_b=True)
    x = tf.nn.bias_add(x, self.bias)
    return tf.nn.softmax(x)
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.out_dim)

# %%
class Pointer(tf.keras.layers.Layer):
  def __init__(self, vocab_size):
    super().__init__()
    self.encoder_ids = None
    self.encoder_out = None
    self.vocab_size = vocab_size
    self.is_beam_search = None

  def call(self, inputs):
    _max_len = tf.shape(self.encoder_ids)[1]
    _batch_size_ori = tf.shape(inputs)[0]
    if self.is_beam_search:
      _batch_size= _batch_size_ori * params['beam_width']
    else:
      _batch_size = _batch_size_ori
    inputs = tf.reshape(inputs, (_batch_size, params['rnn_units']))

    attn_weights = tf.matmul(self.encoder_out, tf.expand_dims(inputs, -1))
    attn_weights = tf.squeeze(attn_weights, -1)
    updates = tf.nn.softmax(attn_weights)
    
    batch_nums = tf.range(0, _batch_size)
    batch_nums = tf.expand_dims(batch_nums, axis=1)
    batch_nums = tf.tile(batch_nums, [1, _max_len])

    indices = tf.stack([batch_nums, self.encoder_ids], axis=2)
    if self.is_beam_search:
      x = tf.scatter_nd(indices, updates, (_batch_size, self.vocab_size))
      return tf.reshape(x, (_batch_size_ori, params['beam_width'], self.vocab_size))
    else:
      x = tf.scatter_nd(indices, updates, (_batch_size, self.vocab_size))
      return x
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.vocab_size)

# %%
class OutputProj(tf.keras.layers.Layer):
  def __init__(self, tied_embed, vocab_size):
    super().__init__()
    self.generator = TiedDense(tied_embed, vocab_size)
    self.pointer = Pointer(vocab_size)
    self.vocab_size = vocab_size

  def build(self, input_shape):
    self.gate_fc = tf.keras.layers.Dense(1, tf.sigmoid, use_bias=False)
    super().build(input_shape)
  
  def call(self, inputs):
    gen_dist = self.generator(inputs)
    copy_dist = self.pointer(inputs)
    gate = self.gate_fc(inputs)
    return gate * gen_dist + (1 - gate) * copy_dist
  
  def compute_output_shape(self, input_shape):
    return input_shape[:-1].concatenate(self.vocab_size)

# %%
class Model(tf.keras.Model):
  def __init__(self, params):
    super().__init__()
    self.embed = Embed()

    self.encoder = Encoder(params)

    self.dropout = tf.keras.layers.Dropout(params['dropout_rate'])

    self.attn = tfa.seq2seq.BahdanauAttention(params['rnn_units'])

    self.decoder_cell = tfa.seq2seq.AttentionWrapper(
      tf.keras.layers.StackedRNNCells([tf.keras.layers.GRUCell(params['rnn_units'])]),
      self.attn,
      attention_layer_size=params['rnn_units'])
    
    self.proj_layer = OutputProj(self.embed.embedding, len(params['tgt2idx'])+1)

    self.teach_forcing = tfa.seq2seq.BasicDecoder(
      self.decoder_cell,
      tfa.seq2seq.sampler.TrainingSampler(),
      output_layer = self.proj_layer)

    self.beam_search = BeamSearchDecoder(
      self.decoder_cell,
      beam_width = params['beam_width'],
      embedding_fn = lambda x: self.embed(x),
      output_layer = self.proj_layer,
      maximum_iterations = 80,)

  
  def call(self, inputs, training=True):
    if training:
      source, target_in = inputs
    else:
      source = inputs
    source = tf.cast(source, tf.int32)
    batch_sz = tf.shape(source)[0]

    encoder_o, encoder_s = self.encoder(self.embed(source), mask=tf.sign(source), training=training)

    if training:
      self.attn([encoder_o, tf.math.count_nonzero(source, 1)], setup_memory=True)
      attn_state = self.decoder_cell.get_initial_state(batch_size=batch_sz, dtype=tf.float32)
      attn_state = attn_state.clone(cell_state=encoder_s)

      self.proj_layer.pointer.encoder_ids = source
      self.proj_layer.pointer.encoder_out = self.encoder.state_fc(encoder_o)
      self.proj_layer.pointer.is_beam_search = False

      decoder_o, _, _ = self.teach_forcing(
        inputs = self.dropout(self.embed(target_in), training=training),
        initial_state = attn_state,
        sequence_length = tf.math.count_nonzero(target_in, 1, dtype=tf.int32))

      logits_or_ids = decoder_o.rnn_output
    else:
      encoder_o_t = tfa.seq2seq.tile_batch(encoder_o, params['beam_width'])
      encoder_len_t = tfa.seq2seq.tile_batch(tf.math.count_nonzero(source, 1), params['beam_width'])
      encoder_s_t = tfa.seq2seq.tile_batch(encoder_s, params['beam_width'])

      self.attn([encoder_o_t, encoder_len_t], setup_memory=True)
      attn_state = self.decoder_cell.get_initial_state(batch_size=batch_sz*params['beam_width'], dtype=tf.float32)
      attn_state = attn_state.clone(cell_state=encoder_s_t)

      self.proj_layer.pointer.encoder_ids = tfa.seq2seq.tile_batch(source, params['beam_width'])
      self.proj_layer.pointer.encoder_out = self.encoder.state_fc(encoder_o_t)
      self.proj_layer.pointer.is_beam_search = True

      decoder_o, _, _ = self.beam_search(
        embedding = None,
        start_tokens = tf.tile(tf.constant([1], tf.int32), [batch_sz]),
        end_token = 2,
        initial_state = attn_state,)

      logits_or_ids = decoder_o.predicted_ids[:, :, 0]

    return logits_or_ids

# %%
def get_vocab(f_path):
  word2idx = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      word2idx[line] = i
  return word2idx

# %%
params = {
    'train_path': '../data/train.tsv',
    'test_path': '../data/test.tsv',
    'vocab_src_path': '../vocab/source.txt',
    'vocab_tgt_path': '../vocab/target.txt',
    'model_path': '../model/',
    'dropout_rate': .2,
    'rnn_units': 300,
    'embed_dim': 300,
    'activation': tf.nn.elu,
    'beam_width': 10,
    'init_lr': 1e-4,
    'max_lr': 8e-4,
    'clip_norm': .1,
    'buffer_size': 31279,
    'train_batch_size': 32,
    'eval_batch_size': 128,
    'num_patience': 10,
}

# %%
params['tgt2idx'] = get_vocab(params['vocab_tgt_path'])
params['idx2tgt'] = {idx: tgt for tgt, idx in params['tgt2idx'].items()}

# %%
model = Model(params)
model.build(input_shape=[[None, None], [None, None]])
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])
# Out:
# [('pretrained_embedding:0', TensorShape([8692, 300])),
#  ('encoder/bidirectional/forward_gru/gru_cell_1/kernel:0',
#   TensorShape([300, 900])),
#  ('encoder/bidirectional/forward_gru/gru_cell_1/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('encoder/bidirectional/forward_gru/gru_cell_1/bias:0', TensorShape([2, 900])),
#  ('encoder/bidirectional/backward_gru/gru_cell_2/kernel:0',
#   TensorShape([300, 900])),
#  ('encoder/bidirectional/backward_gru/gru_cell_2/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('encoder/bidirectional/backward_gru/gru_cell_2/bias:0',
#   TensorShape([2, 900])),
#  ('encoder/state_fc/kernel:0', TensorShape([600, 300])),
#  ('encoder/state_fc/bias:0', TensorShape([300])),
#  ('BahdanauAttention/attention_v:0', TensorShape([300])),
#  ('attention_wrapper/BahdanauAttention/kernel:0', TensorShape([300, 300])),
#  ('BahdanauAttention/kernel:0', TensorShape([600, 300])),
#  ('attention_wrapper/attention_layer/kernel:0', TensorShape([900, 300])),
#  ('attention_wrapper/stacked_rnn_cells/gru_cell_3/kernel:0',
#   TensorShape([600, 900])),
#  ('attention_wrapper/stacked_rnn_cells/gru_cell_3/recurrent_kernel:0',
#   TensorShape([300, 900])),
#  ('attention_wrapper/stacked_rnn_cells/gru_cell_3/bias:0',
#   TensorShape([2, 900])),
#  ('output_proj/tied_dense/bias:0', TensorShape([8692])),
#  ('output_proj/dense/kernel:0', TensorShape([300, 1]))]

# %%
decay_lr = Triangular2CyclicalLearningRate(
  initial_learning_rate = params['init_lr'],
  maximal_learning_rate = params['max_lr'],
  step_size = 4*params['buffer_size']//params['train_batch_size'],)
optim = tf.optimizers.Adam(params['init_lr'])
global_step = 0

# %%
best_acc = .0
count = 0

# %%
t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.propagate = False
logger.setLevel(logging.INFO)

# %%
def minimal_test(model, params):
  test_str = ['what', 'times', 'are', 'the', 'nutcracker', 'show', 'playing', 'near', 'me']
  test_arr = tf.convert_to_tensor([[params['tgt2idx'][w] for w in test_str]])
  generated = model(inputs=test_arr, training=False)

  print('-'*12)
  print('minimal test')
  print('utterance:', ' '.join(test_str))
  parsed = ' '.join([params['idx2tgt'][idx] for idx in generated[0].numpy() if (idx != 0 and idx != 2)])
  print('parsed:', parsed)
  print()
  try:
    nltk.tree.Tree.fromstring(parsed.replace('[ ', '(').replace(' ]', ')')).pretty_print()
  except:
    pass
  print('-'*12)

# %%
def cross_entropy_loss(logits, labels, vocab_size, smoothing):
  soft_targets = tf.one_hot(tf.cast(labels, tf.int32), depth=vocab_size)
  soft_targets = ((1-smoothing) * soft_targets) + (smoothing / vocab_size)

  logits = tf.math.minimum(1., logits + 1e-6)
  log_probs = tf.math.log(logits)
  xentropy = - tf.reduce_sum(soft_targets * log_probs, axis=-1)

  weights = tf.cast(tf.math.not_equal(labels, 0), tf.float32)
  xentropy *= weights
  return tf.reduce_sum(xentropy) / tf.reduce_sum(weights)

# %%
while True:
  # TRAINING
  is_training = True
  for i, (source, target_in, target_out) in enumerate(dataset(is_training=is_training, params=params)):
    with tf.GradientTape() as tape:
      logits_or_ids = model((source, target_in), training=is_training)
      
      loss = cross_entropy_loss(logits_or_ids, target_out, len(params['tgt2idx'])+1, .2)  

    variables = model.trainable_variables
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, variables))
    
    if global_step % 50 == 0:
      logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
        global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    
    global_step += 1

  # EVALUATION
  is_training = False
  minimal_test(model, params)
  m = tf.keras.metrics.Mean()
  
  parse_fn = lambda x: [e for e in x if (e != 0 and e != 2)]

  for i, (source, target_in, target_out) in enumerate(dataset(is_training=is_training, params=params)):
    generated = model(inputs=source, training=is_training)
    for pred, tgt in zip(generated.numpy(), target_out.numpy()):
      matched = np.array_equal(parse_fn(pred), parse_fn(tgt))
      m.update_state(int(matched))
  
  acc = m.result().numpy()
  logger.info("Evaluation: Testing EM: {:.3f}".format(acc))

  if acc > best_acc:
    best_acc = acc
    count = 0
    model.save_weights('../model/gru_pointer_clr')
  else:
    count += 1
  logger.info("Best EM: {:.3f}".format(best_acc))

  if count == params['num_patience']:
    print(params['num_patience'], "times not improve the best result, therefore stop training")
    break
# Out:
# Reading ../data/train.tsv
# INFO:tensorflow:Step 0 | Loss: 8.7499 | Spent: 15.2 secs | LR: 0.000100
# INFO:tensorflow:Step 50 | Loss: 4.7706 | Spent: 52.9 secs | LR: 0.000109
# INFO:tensorflow:Step 100 | Loss: 4.2527 | Spent: 53.9 secs | LR: 0.000118
# INFO:tensorflow:Step 150 | Loss: 3.7944 | Spent: 52.3 secs | LR: 0.000127
# INFO:tensorflow:Step 200 | Loss: 3.7539 | Spent: 55.3 secs | LR: 0.000136
# INFO:tensorflow:Step 250 | Loss: 3.6456 | Spent: 55.0 secs | LR: 0.000145
# INFO:tensorflow:Step 300 | Loss: 3.3645 | Spent: 52.4 secs | LR: 0.000154
# INFO:tensorflow:Step 350 | Loss: 3.3552 | Spent: 53.2 secs | LR: 0.000163
# INFO:tensorflow:Step 400 | Loss: 3.2465 | Spent: 53.6 secs | LR: 0.000172
# INFO:tensorflow:Step 450 | Loss: 3.1739 | Spent: 53.3 secs | LR: 0.000181
# INFO:tensorflow:Step 500 | Loss: 3.1444 | Spent: 53.2 secs | LR: 0.000190
# INFO:tensorflow:Step 550 | Loss: 3.1199 | Spent: 54.3 secs | LR: 0.000198
# INFO:tensorflow:Step 600 | Loss: 3.0393 | Spent: 54.9 secs | LR: 0.000207
# INFO:tensorflow:Step 650 | Loss: 3.0385 | Spent: 52.3 secs | LR: 0.000216
# INFO:tensorflow:Step 700 | Loss: 2.9857 | Spent: 55.9 secs | LR: 0.000225
# INFO:tensorflow:Step 750 | Loss: 2.9490 | Spent: 53.5 secs | LR: 0.000234
# INFO:tensorflow:Step 800 | Loss: 2.9124 | Spent: 53.5 secs | LR: 0.000243
# INFO:tensorflow:Step 850 | Loss: 2.8893 | Spent: 54.9 secs | LR: 0.000252
# INFO:tensorflow:Step 900 | Loss: 2.8314 | Spent: 56.6 secs | LR: 0.000261
# INFO:tensorflow:Step 950 | Loss: 2.8739 | Spent: 55.0 secs | LR: 0.000270
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are the [ sl:location nutcracker ] [ sl:date_time show playing ] [ sl:location [ in:get_location [ sl:location_user near ] [ sl:location_user me ] ] ] ]
#
#                    in:get_event
#   ______________________|_________________________________________________________
#  |     |    |   |       |                 |                                  sl:location
#  |     |    |   |       |                 |                                       |
#  |     |    |   |       |                 |                                in:get_location
#  |     |    |   |       |                 |                       ________________|_______________
#  |     |    |   |  sl:location       sl:date_time         sl:location_user                 sl:location_user
#  |     |    |   |       |         ________|__________            |                                |
# what times are the  nutcracker  show              playing       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.193
# INFO:tensorflow:Best EM: 0.193
# Reading ../data/train.tsv
# INFO:tensorflow:Step 1000 | Loss: 2.7410 | Spent: 300.4 secs | LR: 0.000279
# INFO:tensorflow:Step 1050 | Loss: 2.7070 | Spent: 53.5 secs | LR: 0.000288
# INFO:tensorflow:Step 1100 | Loss: 2.7423 | Spent: 51.2 secs | LR: 0.000297
# INFO:tensorflow:Step 1150 | Loss: 2.7759 | Spent: 51.5 secs | LR: 0.000306
# INFO:tensorflow:Step 1200 | Loss: 2.7442 | Spent: 52.2 secs | LR: 0.000315
# INFO:tensorflow:Step 1250 | Loss: 2.7357 | Spent: 53.0 secs | LR: 0.000324
# INFO:tensorflow:Step 1300 | Loss: 2.6185 | Spent: 52.7 secs | LR: 0.000333
# INFO:tensorflow:Step 1350 | Loss: 2.6548 | Spent: 55.5 secs | LR: 0.000342
# INFO:tensorflow:Step 1400 | Loss: 2.5802 | Spent: 53.6 secs | LR: 0.000351
# INFO:tensorflow:Step 1450 | Loss: 2.5939 | Spent: 51.4 secs | LR: 0.000360
# INFO:tensorflow:Step 1500 | Loss: 2.5262 | Spent: 54.2 secs | LR: 0.000369
# INFO:tensorflow:Step 1550 | Loss: 2.6206 | Spent: 51.4 secs | LR: 0.000378
# INFO:tensorflow:Step 1600 | Loss: 2.6586 | Spent: 52.0 secs | LR: 0.000387
# INFO:tensorflow:Step 1650 | Loss: 2.5356 | Spent: 52.9 secs | LR: 0.000395
# INFO:tensorflow:Step 1700 | Loss: 2.5167 | Spent: 54.0 secs | LR: 0.000404
# INFO:tensorflow:Step 1750 | Loss: 2.5704 | Spent: 52.2 secs | LR: 0.000413
# INFO:tensorflow:Step 1800 | Loss: 2.4839 | Spent: 55.6 secs | LR: 0.000422
# INFO:tensorflow:Step 1850 | Loss: 2.4846 | Spent: 53.4 secs | LR: 0.000431
# INFO:tensorflow:Step 1900 | Loss: 2.4939 | Spent: 53.7 secs | LR: 0.000440
# INFO:tensorflow:Step 1950 | Loss: 2.4965 | Spent: 55.8 secs | LR: 0.000449
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.537
# INFO:tensorflow:Best EM: 0.537
# Reading ../data/train.tsv
# INFO:tensorflow:Step 2000 | Loss: 2.4587 | Spent: 367.6 secs | LR: 0.000458
# INFO:tensorflow:Step 2050 | Loss: 2.5442 | Spent: 52.1 secs | LR: 0.000467
# INFO:tensorflow:Step 2100 | Loss: 2.4681 | Spent: 53.5 secs | LR: 0.000476
# INFO:tensorflow:Step 2150 | Loss: 2.4786 | Spent: 52.2 secs | LR: 0.000485
# INFO:tensorflow:Step 2200 | Loss: 2.5298 | Spent: 52.6 secs | LR: 0.000494
# INFO:tensorflow:Step 2250 | Loss: 2.4430 | Spent: 52.3 secs | LR: 0.000503
# INFO:tensorflow:Step 2300 | Loss: 2.4668 | Spent: 53.7 secs | LR: 0.000512
# INFO:tensorflow:Step 2350 | Loss: 2.4152 | Spent: 51.8 secs | LR: 0.000521
# INFO:tensorflow:Step 2400 | Loss: 2.4646 | Spent: 54.3 secs | LR: 0.000530
# INFO:tensorflow:Step 2450 | Loss: 2.4371 | Spent: 54.9 secs | LR: 0.000539
# INFO:tensorflow:Step 2500 | Loss: 2.4410 | Spent: 52.3 secs | LR: 0.000548
# INFO:tensorflow:Step 2550 | Loss: 2.4218 | Spent: 55.1 secs | LR: 0.000557
# INFO:tensorflow:Step 2600 | Loss: 2.4517 | Spent: 52.7 secs | LR: 0.000566
# INFO:tensorflow:Step 2650 | Loss: 2.4675 | Spent: 54.3 secs | LR: 0.000575
# INFO:tensorflow:Step 2700 | Loss: 2.4091 | Spent: 53.7 secs | LR: 0.000583
# INFO:tensorflow:Step 2750 | Loss: 2.4193 | Spent: 53.3 secs | LR: 0.000592
# INFO:tensorflow:Step 2800 | Loss: 2.4083 | Spent: 52.4 secs | LR: 0.000601
# INFO:tensorflow:Step 2850 | Loss: 2.4438 | Spent: 53.1 secs | LR: 0.000610
# INFO:tensorflow:Step 2900 | Loss: 2.4138 | Spent: 55.4 secs | LR: 0.000619
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.672
# INFO:tensorflow:Best EM: 0.672
# Reading ../data/train.tsv
# INFO:tensorflow:Step 2950 | Loss: 2.4181 | Spent: 337.7 secs | LR: 0.000628
# INFO:tensorflow:Step 3000 | Loss: 2.4535 | Spent: 52.5 secs | LR: 0.000637
# INFO:tensorflow:Step 3050 | Loss: 2.4092 | Spent: 52.6 secs | LR: 0.000646
# INFO:tensorflow:Step 3100 | Loss: 2.3898 | Spent: 51.9 secs | LR: 0.000655
# INFO:tensorflow:Step 3150 | Loss: 2.4017 | Spent: 53.0 secs | LR: 0.000664
# INFO:tensorflow:Step 3200 | Loss: 2.4092 | Spent: 52.6 secs | LR: 0.000673
# INFO:tensorflow:Step 3250 | Loss: 2.4104 | Spent: 52.3 secs | LR: 0.000682
# INFO:tensorflow:Step 3300 | Loss: 2.3995 | Spent: 52.4 secs | LR: 0.000691
# INFO:tensorflow:Step 3350 | Loss: 2.3975 | Spent: 51.1 secs | LR: 0.000700
# INFO:tensorflow:Step 3400 | Loss: 2.3894 | Spent: 52.6 secs | LR: 0.000709
# INFO:tensorflow:Step 3450 | Loss: 2.3960 | Spent: 54.2 secs | LR: 0.000718
# INFO:tensorflow:Step 3500 | Loss: 2.3959 | Spent: 53.3 secs | LR: 0.000727
# INFO:tensorflow:Step 3550 | Loss: 2.4142 | Spent: 54.8 secs | LR: 0.000736
# INFO:tensorflow:Step 3600 | Loss: 2.3881 | Spent: 53.1 secs | LR: 0.000745
# INFO:tensorflow:Step 3650 | Loss: 2.4061 | Spent: 52.5 secs | LR: 0.000754
# INFO:tensorflow:Step 3700 | Loss: 2.3812 | Spent: 52.6 secs | LR: 0.000763
# INFO:tensorflow:Step 3750 | Loss: 2.4229 | Spent: 52.5 secs | LR: 0.000772
# INFO:tensorflow:Step 3800 | Loss: 2.4077 | Spent: 52.5 secs | LR: 0.000780
# INFO:tensorflow:Step 3850 | Loss: 2.3926 | Spent: 54.6 secs | LR: 0.000789
# INFO:tensorflow:Step 3900 | Loss: 2.4032 | Spent: 54.3 secs | LR: 0.000798
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.685
# INFO:tensorflow:Best EM: 0.685
# Reading ../data/train.tsv
# INFO:tensorflow:Step 3950 | Loss: 2.3910 | Spent: 343.1 secs | LR: 0.000793
# INFO:tensorflow:Step 4000 | Loss: 2.4107 | Spent: 54.0 secs | LR: 0.000784
# INFO:tensorflow:Step 4050 | Loss: 2.4011 | Spent: 52.0 secs | LR: 0.000775
# INFO:tensorflow:Step 4100 | Loss: 2.3842 | Spent: 53.4 secs | LR: 0.000766
# INFO:tensorflow:Step 4150 | Loss: 2.3844 | Spent: 50.6 secs | LR: 0.000757
# INFO:tensorflow:Step 4200 | Loss: 2.3718 | Spent: 52.5 secs | LR: 0.000748
# INFO:tensorflow:Step 4250 | Loss: 2.3686 | Spent: 51.7 secs | LR: 0.000739
# INFO:tensorflow:Step 4300 | Loss: 2.3575 | Spent: 53.6 secs | LR: 0.000730
# INFO:tensorflow:Step 4350 | Loss: 2.3606 | Spent: 54.3 secs | LR: 0.000721
# INFO:tensorflow:Step 4400 | Loss: 2.3770 | Spent: 51.4 secs | LR: 0.000712
# INFO:tensorflow:Step 4450 | Loss: 2.3711 | Spent: 53.5 secs | LR: 0.000703
# INFO:tensorflow:Step 4500 | Loss: 2.3938 | Spent: 53.7 secs | LR: 0.000694
# INFO:tensorflow:Step 4550 | Loss: 2.3612 | Spent: 53.4 secs | LR: 0.000685
# INFO:tensorflow:Step 4600 | Loss: 2.3847 | Spent: 51.9 secs | LR: 0.000676
# INFO:tensorflow:Step 4650 | Loss: 2.3570 | Spent: 53.5 secs | LR: 0.000667
# INFO:tensorflow:Step 4700 | Loss: 2.3753 | Spent: 53.2 secs | LR: 0.000658
# INFO:tensorflow:Step 4750 | Loss: 2.3683 | Spent: 54.0 secs | LR: 0.000649
# INFO:tensorflow:Step 4800 | Loss: 2.3750 | Spent: 53.3 secs | LR: 0.000640
# INFO:tensorflow:Step 4850 | Loss: 2.3865 | Spent: 54.4 secs | LR: 0.000631
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.749
# INFO:tensorflow:Best EM: 0.749
# Reading ../data/train.tsv
# INFO:tensorflow:Step 4900 | Loss: 2.3553 | Spent: 355.9 secs | LR: 0.000623
# INFO:tensorflow:Step 4950 | Loss: 2.3538 | Spent: 53.2 secs | LR: 0.000614
# INFO:tensorflow:Step 5000 | Loss: 2.3621 | Spent: 53.2 secs | LR: 0.000605
# INFO:tensorflow:Step 5050 | Loss: 2.3700 | Spent: 56.2 secs | LR: 0.000596
# INFO:tensorflow:Step 5100 | Loss: 2.3666 | Spent: 56.1 secs | LR: 0.000587
# INFO:tensorflow:Step 5150 | Loss: 2.3434 | Spent: 53.2 secs | LR: 0.000578
# INFO:tensorflow:Step 5200 | Loss: 2.3588 | Spent: 54.0 secs | LR: 0.000569
# INFO:tensorflow:Step 5250 | Loss: 2.3645 | Spent: 53.9 secs | LR: 0.000560
# INFO:tensorflow:Step 5300 | Loss: 2.3524 | Spent: 53.3 secs | LR: 0.000551
# INFO:tensorflow:Step 5350 | Loss: 2.3445 | Spent: 53.6 secs | LR: 0.000542
# INFO:tensorflow:Step 5400 | Loss: 2.3568 | Spent: 53.7 secs | LR: 0.000533
# INFO:tensorflow:Step 5450 | Loss: 2.3412 | Spent: 53.4 secs | LR: 0.000524
# INFO:tensorflow:Step 5500 | Loss: 2.3529 | Spent: 54.5 secs | LR: 0.000515
# INFO:tensorflow:Step 5550 | Loss: 2.3480 | Spent: 56.1 secs | LR: 0.000506
# INFO:tensorflow:Step 5600 | Loss: 2.3461 | Spent: 54.4 secs | LR: 0.000497
# INFO:tensorflow:Step 5650 | Loss: 2.3450 | Spent: 55.7 secs | LR: 0.000488
# INFO:tensorflow:Step 5700 | Loss: 2.3640 | Spent: 54.9 secs | LR: 0.000479
# INFO:tensorflow:Step 5750 | Loss: 2.3629 | Spent: 52.4 secs | LR: 0.000470
# INFO:tensorflow:Step 5800 | Loss: 2.3341 | Spent: 54.6 secs | LR: 0.000461
# INFO:tensorflow:Step 5850 | Loss: 2.3432 | Spent: 57.9 secs | LR: 0.000452
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.776
# INFO:tensorflow:Best EM: 0.776
# Reading ../data/train.tsv
# INFO:tensorflow:Step 5900 | Loss: 2.3335 | Spent: 362.7 secs | LR: 0.000443
# INFO:tensorflow:Step 5950 | Loss: 2.3444 | Spent: 53.7 secs | LR: 0.000435
# INFO:tensorflow:Step 6000 | Loss: 2.3396 | Spent: 56.3 secs | LR: 0.000426
# INFO:tensorflow:Step 6050 | Loss: 2.3348 | Spent: 54.6 secs | LR: 0.000417
# INFO:tensorflow:Step 6100 | Loss: 2.3389 | Spent: 51.9 secs | LR: 0.000408
# INFO:tensorflow:Step 6150 | Loss: 2.3480 | Spent: 52.4 secs | LR: 0.000399
# INFO:tensorflow:Step 6200 | Loss: 2.3323 | Spent: 53.4 secs | LR: 0.000390
# INFO:tensorflow:Step 6250 | Loss: 2.3366 | Spent: 52.9 secs | LR: 0.000381
# INFO:tensorflow:Step 6300 | Loss: 2.3352 | Spent: 51.4 secs | LR: 0.000372
# INFO:tensorflow:Step 6350 | Loss: 2.3483 | Spent: 52.6 secs | LR: 0.000363
# INFO:tensorflow:Step 6400 | Loss: 2.3653 | Spent: 54.4 secs | LR: 0.000354
# INFO:tensorflow:Step 6450 | Loss: 2.3435 | Spent: 56.4 secs | LR: 0.000345
# INFO:tensorflow:Step 6500 | Loss: 2.3556 | Spent: 53.5 secs | LR: 0.000336
# INFO:tensorflow:Step 6550 | Loss: 2.3473 | Spent: 52.5 secs | LR: 0.000327
# INFO:tensorflow:Step 6600 | Loss: 2.3425 | Spent: 52.7 secs | LR: 0.000318
# INFO:tensorflow:Step 6650 | Loss: 2.3271 | Spent: 52.1 secs | LR: 0.000309
# INFO:tensorflow:Step 6700 | Loss: 2.3467 | Spent: 53.5 secs | LR: 0.000300
# INFO:tensorflow:Step 6750 | Loss: 2.3392 | Spent: 53.2 secs | LR: 0.000291
# INFO:tensorflow:Step 6800 | Loss: 2.3416 | Spent: 56.0 secs | LR: 0.000282
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.779
# INFO:tensorflow:Best EM: 0.779
# Reading ../data/train.tsv
# INFO:tensorflow:Step 6850 | Loss: 2.3313 | Spent: 352.0 secs | LR: 0.000273
# INFO:tensorflow:Step 6900 | Loss: 2.3412 | Spent: 53.0 secs | LR: 0.000264
# INFO:tensorflow:Step 6950 | Loss: 2.3418 | Spent: 55.1 secs | LR: 0.000255
# INFO:tensorflow:Step 7000 | Loss: 2.3416 | Spent: 51.3 secs | LR: 0.000246
# INFO:tensorflow:Step 7050 | Loss: 2.3313 | Spent: 52.6 secs | LR: 0.000238
# INFO:tensorflow:Step 7100 | Loss: 2.3307 | Spent: 52.2 secs | LR: 0.000229
# INFO:tensorflow:Step 7150 | Loss: 2.3361 | Spent: 52.9 secs | LR: 0.000220
# INFO:tensorflow:Step 7200 | Loss: 2.3263 | Spent: 53.2 secs | LR: 0.000211
# INFO:tensorflow:Step 7250 | Loss: 2.3271 | Spent: 52.3 secs | LR: 0.000202
# INFO:tensorflow:Step 7300 | Loss: 2.3330 | Spent: 51.8 secs | LR: 0.000193
# INFO:tensorflow:Step 7350 | Loss: 2.3333 | Spent: 52.1 secs | LR: 0.000184
# INFO:tensorflow:Step 7400 | Loss: 2.3241 | Spent: 52.3 secs | LR: 0.000175
# INFO:tensorflow:Step 7450 | Loss: 2.3337 | Spent: 53.0 secs | LR: 0.000166
# INFO:tensorflow:Step 7500 | Loss: 2.3377 | Spent: 51.5 secs | LR: 0.000157
# INFO:tensorflow:Step 7550 | Loss: 2.3331 | Spent: 52.9 secs | LR: 0.000148
# INFO:tensorflow:Step 7600 | Loss: 2.3256 | Spent: 51.3 secs | LR: 0.000139
# INFO:tensorflow:Step 7650 | Loss: 2.3272 | Spent: 52.5 secs | LR: 0.000130
# INFO:tensorflow:Step 7700 | Loss: 2.3487 | Spent: 53.8 secs | LR: 0.000121
# INFO:tensorflow:Step 7750 | Loss: 2.3375 | Spent: 51.7 secs | LR: 0.000112
# INFO:tensorflow:Step 7800 | Loss: 2.3477 | Spent: 53.9 secs | LR: 0.000103
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.803
# INFO:tensorflow:Best EM: 0.803
# Reading ../data/train.tsv
# INFO:tensorflow:Step 7850 | Loss: 2.3643 | Spent: 356.9 secs | LR: 0.000103
# INFO:tensorflow:Step 7900 | Loss: 2.3314 | Spent: 52.9 secs | LR: 0.000107
# INFO:tensorflow:Step 7950 | Loss: 2.3293 | Spent: 52.5 secs | LR: 0.000112
# INFO:tensorflow:Step 8000 | Loss: 2.3260 | Spent: 53.3 secs | LR: 0.000116
# INFO:tensorflow:Step 8050 | Loss: 2.3249 | Spent: 53.1 secs | LR: 0.000121
# INFO:tensorflow:Step 8100 | Loss: 2.3282 | Spent: 51.0 secs | LR: 0.000125
# INFO:tensorflow:Step 8150 | Loss: 2.3261 | Spent: 50.1 secs | LR: 0.000130
# INFO:tensorflow:Step 8200 | Loss: 2.3262 | Spent: 53.5 secs | LR: 0.000134
# INFO:tensorflow:Step 8250 | Loss: 2.3350 | Spent: 52.9 secs | LR: 0.000139
# INFO:tensorflow:Step 8300 | Loss: 2.3372 | Spent: 52.1 secs | LR: 0.000143
# INFO:tensorflow:Step 8350 | Loss: 2.3346 | Spent: 51.9 secs | LR: 0.000148
# INFO:tensorflow:Step 8400 | Loss: 2.3299 | Spent: 51.8 secs | LR: 0.000152
# INFO:tensorflow:Step 8450 | Loss: 2.3379 | Spent: 52.3 secs | LR: 0.000157
# INFO:tensorflow:Step 8500 | Loss: 2.3247 | Spent: 54.0 secs | LR: 0.000161
# INFO:tensorflow:Step 8550 | Loss: 2.3243 | Spent: 52.9 secs | LR: 0.000166
# INFO:tensorflow:Step 8600 | Loss: 2.3200 | Spent: 52.7 secs | LR: 0.000170
# INFO:tensorflow:Step 8650 | Loss: 2.3221 | Spent: 54.1 secs | LR: 0.000174
# INFO:tensorflow:Step 8700 | Loss: 2.3271 | Spent: 53.8 secs | LR: 0.000179
# INFO:tensorflow:Step 8750 | Loss: 2.3229 | Spent: 55.4 secs | LR: 0.000183
# INFO:tensorflow:Step 8800 | Loss: 2.3259 | Spent: 49.4 secs | LR: 0.000188
# ------------
# minimal test
# utterance: what times are the nutcracker show playing near me
# parsed: [ in:get_event what times are [ sl:category_event the nutcracker show ] playing [ sl:location [ in:get_location [ sl:search_radius near ] [ sl:location_user me ] ] ] ]
#
#                        in:get_event
#   __________________________|_____________________________________________________
#  |     |    |     |                        |                                 sl:location
#  |     |    |     |                        |                                      |
#  |     |    |     |                        |                               in:get_location
#  |     |    |     |                        |                      ________________|_______________
#  |     |    |     |                 sl:category_even      sl:search_radius                 sl:location_user
#  |     |    |     |                        t                     |                                |
#  |     |    |     |          ______________|__________           |                                |
# what times are playing     the         nutcracker    show       near                              me
#
# ------------
# Reading ../data/test.tsv
# INFO:tensorflow:Evaluation: Testing EM: 0.791
# INFO:tensorflow:Best EM: 0.803
# Reading ../data/train.tsv
