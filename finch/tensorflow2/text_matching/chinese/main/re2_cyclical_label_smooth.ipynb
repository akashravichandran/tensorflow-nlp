# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('/content/gdrive/My Drive/finch/tensorflow2/text_matching/chinese/main')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %tensorflow_version 2.x
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons) (2.7.1)

# %%
import csv
import tensorflow as tf
import numpy as np
import pprint
import logging
import time
import math

from tensorflow_addons.optimizers.cyclical_learning_rate import CyclicalLearningRate

print("TensorFlow Version", tf.__version__)
print('GPU Enabled:', tf.test.is_gpu_available())
# Out:
# TensorFlow Version 2.2.0-rc2
# WARNING:tensorflow:From <ipython-input-3-24f82ec5174c>:12: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU Enabled: True

# %%
def get_vocab(f_path):
  k2v = {}
  with open(f_path) as f:
    for i, line in enumerate(f):
      line = line.rstrip()
      k2v[line] = i
  return k2v

# %%
# stream data from text files
def data_generator(f_path, char2idx):
  with open(f_path) as f:
    print('Reading', f_path)
    for i, line in enumerate(csv.reader(f, delimiter=',')):
      if i == 0:
        continue
      text1, text2, label = line
      text1 = [char2idx.get(c, len(char2idx)) for c in list(text1)]
      text2 = [char2idx.get(c, len(char2idx)) for c in list(text2)]
      yield ((text1, text2), int(label))


def dataset(is_training, params):
  _shapes = (([None], [None]), ())
  _types = ((tf.int32, tf.int32), tf.int32)
  _pads = ((0, 0), -1)
  
  if is_training:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['train_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.shuffle(params['buffer_size'])
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  else:
    ds = tf.data.Dataset.from_generator(
      lambda: data_generator(params['test_path'], params['char2idx']),
      output_shapes = _shapes,
      output_types = _types,)
    ds = ds.padded_batch(params['batch_size'], _shapes, _pads)
  
  return ds

# %%
class RE2(tf.keras.Model):
  def __init__(self, params: dict):
    super().__init__()
    
    self.pretrained_embedding = tf.Variable(np.load(params['embedding_path']), name='pretrained_embedding', dtype=tf.float32)
    self.embed_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.birnn = [tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(
        params['hidden_size'], return_sequences=True), name='birnn_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.enc_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.align_t = self.add_weight(name='temperature',
                                   shape=(),
                                   trainable=True,
                                   initializer=tf.initializers.constant(math.sqrt(1/params['hidden_size'])))
    self.align_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    self.align_fc1 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='align_fc1_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.align_fc2 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='align_fc2_%d'%(i+1)) for i in range(params['num_blocks'])]
      
    self.fusion_fc1 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc1_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc2 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc2_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc3 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc3_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_fc4 = [tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='fusion_fc4_%d'%(i+1)) for i in range(params['num_blocks'])]
    self.fusion_dropout = tf.keras.layers.Dropout(params['dropout_rate'])
    
    self.out_drop1 = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_fc = tf.keras.layers.Dense(params['hidden_size'], params['activation'], name='out_fc')
    self.out_drop2 = tf.keras.layers.Dropout(params['dropout_rate'])
    self.out_linear = tf.keras.layers.Dense(1, name='out_linear')
    
  
  
  def call(self, inputs, training=False):
    x1, x2 = inputs
    
    if x1.dtype != tf.int32:
      x1 = tf.cast(x1, tf.int32)
    if x2.dtype != tf.int32:
      x2 = tf.cast(x2, tf.int32)
    
    batch_sz = tf.shape(x1)[0]
    
    mask1 = tf.sign(x1)
    mask2 = tf.sign(x2)
    
    x1 = self.embedding(x1, training=training)
    x2 = self.embedding(x2, training=training)
    
    res_x1, res_x2 = x1, x2
    
    for i in range(params['num_blocks']):
      
      if i > 0:
        x1 = self.connection(x1, res_x1, i)
        x2 = self.connection(x2, res_x2, i)
        res_x1, res_x2 = x1, x2
    
      x1_enc = self.encoding(x1, mask1, i, training=training)
      x2_enc = self.encoding(x2, mask2, i, training=training)
    
      x1 = tf.concat((x1, x1_enc), -1)
      x2 = tf.concat((x2, x2_enc), -1)
      
      align_1, align_2 = self.alignment(x1, x2, mask1, mask2, i, training=training)
      
      x1 = self.fusion(x1, align_1, i, training=training)
      x2 = self.fusion(x2, align_2, i, training=training)
    
    x1 = self.pooling(x1, mask1)
    x2 = self.pooling(x2, mask2)
    
    x = self.prediction(x1, x2, training=training)
    
    return x
  
  
  def embedding(self, x, training):
    x = tf.nn.embedding_lookup(self.pretrained_embedding, x)
    x = self.embed_dropout(x, training=training)
    return x
  
  
  def connection(self, x, res, i):
    if i == 1:
      x = tf.concat((res, x), -1)
    elif i > 1:
      hidden_size = x.shape[-1]
      x = (res[:, :, -hidden_size:] + x) * tf.math.sqrt(0.5)
      x = tf.concat((res[:, :, :-hidden_size], x), -1)
    return x
    
    
  def encoding(self, x, mask, i, training):
    mask = tf.cast(tf.expand_dims(mask, -1), tf.float32)
    x *= mask
    x = self.birnn[i](x)
    x = self.enc_dropout(x, training=training)
    return x
  
  
  def alignment(self, x1, x2, mask1, mask2, i, training):
    mask1 = tf.cast(tf.expand_dims(mask1, -1), tf.float32)
    mask2 = tf.cast(tf.expand_dims(mask2, -1), tf.float32)
    
    x1_ = self.align_fc1[i](self.align_dropout(x1, training=training))
    x2_ = self.align_fc2[i](self.align_dropout(x2, training=training))
    align = tf.matmul(x1_, x2_, transpose_b=True) * self.align_t
    mask = tf.matmul(mask1, mask2, transpose_b=True)
    align = mask * align + (1 - mask) * tf.float32.min
    align_1 = tf.nn.softmax(align, 1)
    align_2 = tf.nn.softmax(align, 2)
    
    x2 = tf.matmul(align_1, x1, transpose_a=True)
    x1 = tf.matmul(align_2, x2)
    return x1, x2
  
  
  def fusion(self, x, align, i, training):
    x = tf.concat([self.fusion_fc1[i](tf.concat((x, align), -1)),
                   self.fusion_fc2[i](tf.concat((x, x - align), -1)),
                   self.fusion_fc3[i](tf.concat((x, x * align), -1))], -1)
    x = self.fusion_dropout(x, training=training)
    x = self.fusion_fc4[i](x)
    return x
  
  
  def pooling(self, x, mask):
    mask = tf.cast(tf.expand_dims(mask, -1), tf.float32)
    return tf.reduce_max(x * mask, 1)
  
  
  def prediction(self, x1, x2, training):
    x = tf.concat((x1, x2, x1 * x2, x1 - x2), -1)
    x = self.out_drop1(x, training=training)
    x = self.out_fc(x)
    x = self.out_drop2(x, training=training)
    x = self.out_linear(x)
    x = tf.squeeze(x, 1)
    return x

# %%
params = {
  'train_path': '../data/train.csv',
  'test_path': '../data/test.csv',
  'vocab_path': '../vocab/char.txt',
  'embedding_path': '../vocab/char.npy',
  'batch_size': 32,
  'buffer_size': 100000,
  'num_blocks': 2,
  'dropout_rate': 0.2,
  'hidden_size': 300,
  'activation': tf.nn.relu,
  'init_lr': 1e-4,
  'max_lr': 1e-3,
  'label_smooth': .2,
  'clip_norm': 5.,
  'num_patience': 5,
}

# %%
def label_smoothing(inputs, epsilon):
  V = inputs.get_shape().as_list()[-1]
  return ((1-epsilon) * inputs) + (epsilon / V)


def is_descending(history):
  history = history[-(params['num_patience']+1):]
  for i in range(1, len(history)):
    if history[i-1] <= history[i]:
      return False
  return True

# %%
params['char2idx'] = get_vocab(params['vocab_path'])
params['vocab_size'] = len(params['char2idx']) + 1

model = RE2(params)
model.build([[None, None], [None, None]])
pprint.pprint([(v.name, v.shape) for v in model.trainable_variables])

decay_lr = CyclicalLearningRate(
  initial_learning_rate=params['init_lr'],
  maximal_learning_rate=params['max_lr'],
  step_size=6000,
  scale_fn=lambda x: 1.,
  scale_mode='cycle',)
optim = tf.optimizers.Adam(params['init_lr'])
global_step = 0

history_acc = []
best_acc = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

while True:
  # TRAINING
  for ((text1, text2), labels) in dataset(is_training=True, params=params):
    with tf.GradientTape() as tape:
      logits = model((text1, text2), training=True)
      loss = tf.nn.sigmoid_cross_entropy_with_logits(
        labels=label_smoothing(tf.cast(labels, tf.float32), params['label_smooth']),
        logits=logits)
      loss = tf.reduce_mean(loss)
      
    optim.lr.assign(decay_lr(global_step))
    grads = tape.gradient(loss, model.trainable_variables)
    grads, _ = tf.clip_by_global_norm(grads, params['clip_norm'])
    optim.apply_gradients(zip(grads, model.trainable_variables))
    
    if global_step % 100 == 0:
      logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
          global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
      t0 = time.time()
    global_step += 1
  
  # EVALUATION
  m = tf.keras.metrics.Accuracy()

  for ((text1, text2), labels) in dataset(is_training=False, params=params):
    logits = tf.sigmoid(model((text1, text2), training=False))
    y_pred = tf.cast(tf.math.greater_equal(logits, .5), tf.int32)
    m.update_state(y_true=labels, y_pred=y_pred)

  acc = m.result().numpy()
  logger.info("Evaluation: Testing Accuracy: {:.3f}".format(acc))
  history_acc.append(acc)

  if acc > best_acc:
    best_acc = acc
    # you can save model here
  logger.info("Best Accuracy: {:.3f}".format(best_acc))

  if len(history_acc) > params['num_patience'] and is_descending(history_acc):
    logger.info("Testing Accuracy not improved over {} epochs, Early Stop".format(params['num_patience']))
    break
# Out:
# [('birnn_1/forward_lstm_3/lstm_cell_10/kernel:0', TensorShape([300, 1200])),
#  ('birnn_1/forward_lstm_3/lstm_cell_10/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_1/forward_lstm_3/lstm_cell_10/bias:0', TensorShape([1200])),
#  ('birnn_1/backward_lstm_3/lstm_cell_11/kernel:0', TensorShape([300, 1200])),
#  ('birnn_1/backward_lstm_3/lstm_cell_11/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_1/backward_lstm_3/lstm_cell_11/bias:0', TensorShape([1200])),
#  ('birnn_2/forward_lstm_4/lstm_cell_13/kernel:0', TensorShape([600, 1200])),
#  ('birnn_2/forward_lstm_4/lstm_cell_13/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_2/forward_lstm_4/lstm_cell_13/bias:0', TensorShape([1200])),
#  ('birnn_2/backward_lstm_4/lstm_cell_14/kernel:0', TensorShape([600, 1200])),
#  ('birnn_2/backward_lstm_4/lstm_cell_14/recurrent_kernel:0',
#   TensorShape([300, 1200])),
#  ('birnn_2/backward_lstm_4/lstm_cell_14/bias:0', TensorShape([1200])),
#  ('align_fc1_1/kernel:0', TensorShape([900, 300])),
#  ('align_fc1_1/bias:0', TensorShape([300])),
#  ('align_fc1_2/kernel:0', TensorShape([1200, 300])),
#  ('align_fc1_2/bias:0', TensorShape([300])),
#  ('align_fc2_1/kernel:0', TensorShape([900, 300])),
#  ('align_fc2_1/bias:0', TensorShape([300])),
#  ('align_fc2_2/kernel:0', TensorShape([1200, 300])),
#  ('align_fc2_2/bias:0', TensorShape([300])),
#  ('fusion_fc1_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc1_1/bias:0', TensorShape([300])),
#  ('fusion_fc1_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc1_2/bias:0', TensorShape([300])),
#  ('fusion_fc2_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc2_1/bias:0', TensorShape([300])),
#  ('fusion_fc2_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc2_2/bias:0', TensorShape([300])),
#  ('fusion_fc3_1/kernel:0', TensorShape([1800, 300])),
#  ('fusion_fc3_1/bias:0', TensorShape([300])),
#  ('fusion_fc3_2/kernel:0', TensorShape([2400, 300])),
#  ('fusion_fc3_2/bias:0', TensorShape([300])),
#  ('fusion_fc4_1/kernel:0', TensorShape([900, 300])),
#  ('fusion_fc4_1/bias:0', TensorShape([300])),
#  ('fusion_fc4_2/kernel:0', TensorShape([900, 300])),
#  ('fusion_fc4_2/bias:0', TensorShape([300])),
#  ('out_fc/kernel:0', TensorShape([1200, 300])),
#  ('out_fc/bias:0', TensorShape([300])),
#  ('out_linear/kernel:0', TensorShape([300, 1])),
#  ('out_linear/bias:0', TensorShape([1])),
#  ('pretrained_embedding:0', TensorShape([1507, 300])),
#  ('temperature:0', TensorShape([]))]
# Reading ../data/train.csv
# INFO:tensorflow:Step 0 | Loss: 0.6795 | Spent: 16.7 secs | LR: 0.000100
# INFO:tensorflow:Step 100 | Loss: 0.6659 | Spent: 11.4 secs | LR: 0.000115
# INFO:tensorflow:Step 200 | Loss: 0.6376 | Spent: 11.3 secs | LR: 0.000130
# INFO:tensorflow:Step 300 | Loss: 0.5896 | Spent: 11.3 secs | LR: 0.000145
# INFO:tensorflow:Step 400 | Loss: 0.6542 | Spent: 11.3 secs | LR: 0.000160
# INFO:tensorflow:Step 500 | Loss: 0.6518 | Spent: 11.2 secs | LR: 0.000175
# INFO:tensorflow:Step 600 | Loss: 0.6009 | Spent: 11.2 secs | LR: 0.000190
# INFO:tensorflow:Step 700 | Loss: 0.6063 | Spent: 11.2 secs | LR: 0.000205
# INFO:tensorflow:Step 800 | Loss: 0.6434 | Spent: 11.0 secs | LR: 0.000220
# INFO:tensorflow:Step 900 | Loss: 0.6794 | Spent: 11.3 secs | LR: 0.000235
# INFO:tensorflow:Step 1000 | Loss: 0.6075 | Spent: 11.2 secs | LR: 0.000250
# INFO:tensorflow:Step 1100 | Loss: 0.6043 | Spent: 11.4 secs | LR: 0.000265
# INFO:tensorflow:Step 1200 | Loss: 0.7628 | Spent: 11.3 secs | LR: 0.000280
# INFO:tensorflow:Step 1300 | Loss: 0.6341 | Spent: 11.2 secs | LR: 0.000295
# INFO:tensorflow:Step 1400 | Loss: 0.5657 | Spent: 11.4 secs | LR: 0.000310
# INFO:tensorflow:Step 1500 | Loss: 0.6013 | Spent: 11.2 secs | LR: 0.000325
# INFO:tensorflow:Step 1600 | Loss: 0.6637 | Spent: 11.3 secs | LR: 0.000340
# INFO:tensorflow:Step 1700 | Loss: 0.6573 | Spent: 11.2 secs | LR: 0.000355
# INFO:tensorflow:Step 1800 | Loss: 0.6051 | Spent: 11.5 secs | LR: 0.000370
# INFO:tensorflow:Step 1900 | Loss: 0.5544 | Spent: 11.2 secs | LR: 0.000385
# INFO:tensorflow:Step 2000 | Loss: 0.5890 | Spent: 11.3 secs | LR: 0.000400
# INFO:tensorflow:Step 2100 | Loss: 0.4597 | Spent: 11.3 secs | LR: 0.000415
# INFO:tensorflow:Step 2200 | Loss: 0.6085 | Spent: 11.2 secs | LR: 0.000430
# INFO:tensorflow:Step 2300 | Loss: 0.6249 | Spent: 11.2 secs | LR: 0.000445
# INFO:tensorflow:Step 2400 | Loss: 0.5606 | Spent: 11.1 secs | LR: 0.000460
# INFO:tensorflow:Step 2500 | Loss: 0.5868 | Spent: 11.4 secs | LR: 0.000475
# INFO:tensorflow:Step 2600 | Loss: 0.5713 | Spent: 11.2 secs | LR: 0.000490
# INFO:tensorflow:Step 2700 | Loss: 0.5343 | Spent: 11.4 secs | LR: 0.000505
# INFO:tensorflow:Step 2800 | Loss: 0.6382 | Spent: 11.2 secs | LR: 0.000520
# INFO:tensorflow:Step 2900 | Loss: 0.4254 | Spent: 11.4 secs | LR: 0.000535
# INFO:tensorflow:Step 3000 | Loss: 0.4018 | Spent: 11.1 secs | LR: 0.000550
# INFO:tensorflow:Step 3100 | Loss: 0.3999 | Spent: 11.4 secs | LR: 0.000565
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.752
# INFO:tensorflow:Best Accuracy: 0.752
# Reading ../data/train.csv
# INFO:tensorflow:Step 3200 | Loss: 0.5409 | Spent: 44.9 secs | LR: 0.000580
# INFO:tensorflow:Step 3300 | Loss: 0.4966 | Spent: 11.1 secs | LR: 0.000595
# INFO:tensorflow:Step 3400 | Loss: 0.4518 | Spent: 11.3 secs | LR: 0.000610
# INFO:tensorflow:Step 3500 | Loss: 0.4584 | Spent: 11.2 secs | LR: 0.000625
# INFO:tensorflow:Step 3600 | Loss: 0.5779 | Spent: 11.4 secs | LR: 0.000640
# INFO:tensorflow:Step 3700 | Loss: 0.5054 | Spent: 11.1 secs | LR: 0.000655
# INFO:tensorflow:Step 3800 | Loss: 0.4703 | Spent: 11.1 secs | LR: 0.000670
# INFO:tensorflow:Step 3900 | Loss: 0.4636 | Spent: 11.4 secs | LR: 0.000685
# INFO:tensorflow:Step 4000 | Loss: 0.4606 | Spent: 11.1 secs | LR: 0.000700
# INFO:tensorflow:Step 4100 | Loss: 0.6156 | Spent: 11.3 secs | LR: 0.000715
# INFO:tensorflow:Step 4200 | Loss: 0.4773 | Spent: 11.2 secs | LR: 0.000730
# INFO:tensorflow:Step 4300 | Loss: 0.4906 | Spent: 11.2 secs | LR: 0.000745
# INFO:tensorflow:Step 4400 | Loss: 0.4690 | Spent: 11.2 secs | LR: 0.000760
# INFO:tensorflow:Step 4500 | Loss: 0.5291 | Spent: 11.1 secs | LR: 0.000775
# INFO:tensorflow:Step 4600 | Loss: 0.4728 | Spent: 11.3 secs | LR: 0.000790
# INFO:tensorflow:Step 4700 | Loss: 0.5559 | Spent: 11.4 secs | LR: 0.000805
# INFO:tensorflow:Step 4800 | Loss: 0.4993 | Spent: 11.2 secs | LR: 0.000820
# INFO:tensorflow:Step 4900 | Loss: 0.4212 | Spent: 11.3 secs | LR: 0.000835
# INFO:tensorflow:Step 5000 | Loss: 0.3744 | Spent: 11.3 secs | LR: 0.000850
# INFO:tensorflow:Step 5100 | Loss: 0.4789 | Spent: 11.3 secs | LR: 0.000865
# INFO:tensorflow:Step 5200 | Loss: 0.4261 | Spent: 11.3 secs | LR: 0.000880
# INFO:tensorflow:Step 5300 | Loss: 0.4387 | Spent: 11.1 secs | LR: 0.000895
# INFO:tensorflow:Step 5400 | Loss: 0.4187 | Spent: 11.2 secs | LR: 0.000910
# INFO:tensorflow:Step 5500 | Loss: 0.4366 | Spent: 11.4 secs | LR: 0.000925
# INFO:tensorflow:Step 5600 | Loss: 0.4028 | Spent: 11.3 secs | LR: 0.000940
# INFO:tensorflow:Step 5700 | Loss: 0.4283 | Spent: 11.3 secs | LR: 0.000955
# INFO:tensorflow:Step 5800 | Loss: 0.4339 | Spent: 11.2 secs | LR: 0.000970
# INFO:tensorflow:Step 5900 | Loss: 0.4647 | Spent: 11.0 secs | LR: 0.000985
# INFO:tensorflow:Step 6000 | Loss: 0.5626 | Spent: 11.2 secs | LR: 0.001000
# INFO:tensorflow:Step 6100 | Loss: 0.3863 | Spent: 11.3 secs | LR: 0.000985
# INFO:tensorflow:Step 6200 | Loss: 0.5280 | Spent: 11.0 secs | LR: 0.000970
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.798
# INFO:tensorflow:Best Accuracy: 0.798
# Reading ../data/train.csv
# INFO:tensorflow:Step 6300 | Loss: 0.3547 | Spent: 44.2 secs | LR: 0.000955
# INFO:tensorflow:Step 6400 | Loss: 0.5498 | Spent: 11.2 secs | LR: 0.000940
# INFO:tensorflow:Step 6500 | Loss: 0.3005 | Spent: 11.1 secs | LR: 0.000925
# INFO:tensorflow:Step 6600 | Loss: 0.3398 | Spent: 10.9 secs | LR: 0.000910
# INFO:tensorflow:Step 6700 | Loss: 0.4882 | Spent: 10.9 secs | LR: 0.000895
# INFO:tensorflow:Step 6800 | Loss: 0.6408 | Spent: 10.9 secs | LR: 0.000880
# INFO:tensorflow:Step 6900 | Loss: 0.4448 | Spent: 11.1 secs | LR: 0.000865
# INFO:tensorflow:Step 7000 | Loss: 0.5030 | Spent: 11.0 secs | LR: 0.000850
# INFO:tensorflow:Step 7100 | Loss: 0.4353 | Spent: 11.0 secs | LR: 0.000835
# INFO:tensorflow:Step 7200 | Loss: 0.3952 | Spent: 10.8 secs | LR: 0.000820
# INFO:tensorflow:Step 7300 | Loss: 0.5123 | Spent: 11.0 secs | LR: 0.000805
# INFO:tensorflow:Step 7400 | Loss: 0.4920 | Spent: 11.0 secs | LR: 0.000790
# INFO:tensorflow:Step 7500 | Loss: 0.4987 | Spent: 11.1 secs | LR: 0.000775
# INFO:tensorflow:Step 7600 | Loss: 0.4710 | Spent: 11.2 secs | LR: 0.000760
# INFO:tensorflow:Step 7700 | Loss: 0.6078 | Spent: 11.2 secs | LR: 0.000745
# INFO:tensorflow:Step 7800 | Loss: 0.3481 | Spent: 11.1 secs | LR: 0.000730
# INFO:tensorflow:Step 7900 | Loss: 0.4773 | Spent: 11.4 secs | LR: 0.000715
# INFO:tensorflow:Step 8000 | Loss: 0.4314 | Spent: 11.2 secs | LR: 0.000700
# INFO:tensorflow:Step 8100 | Loss: 0.4637 | Spent: 11.1 secs | LR: 0.000685
# INFO:tensorflow:Step 8200 | Loss: 0.5348 | Spent: 11.2 secs | LR: 0.000670
# INFO:tensorflow:Step 8300 | Loss: 0.4371 | Spent: 11.0 secs | LR: 0.000655
# INFO:tensorflow:Step 8400 | Loss: 0.3781 | Spent: 11.3 secs | LR: 0.000640
# INFO:tensorflow:Step 8500 | Loss: 0.3862 | Spent: 11.1 secs | LR: 0.000625
# INFO:tensorflow:Step 8600 | Loss: 0.4855 | Spent: 11.2 secs | LR: 0.000610
# INFO:tensorflow:Step 8700 | Loss: 0.4731 | Spent: 11.5 secs | LR: 0.000595
# INFO:tensorflow:Step 8800 | Loss: 0.4870 | Spent: 11.2 secs | LR: 0.000580
# INFO:tensorflow:Step 8900 | Loss: 0.4148 | Spent: 11.3 secs | LR: 0.000565
# INFO:tensorflow:Step 9000 | Loss: 0.3520 | Spent: 11.4 secs | LR: 0.000550
# INFO:tensorflow:Step 9100 | Loss: 0.4310 | Spent: 11.5 secs | LR: 0.000535
# INFO:tensorflow:Step 9200 | Loss: 0.3359 | Spent: 11.6 secs | LR: 0.000520
# INFO:tensorflow:Step 9300 | Loss: 0.3410 | Spent: 11.2 secs | LR: 0.000505
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.828
# INFO:tensorflow:Best Accuracy: 0.828
# Reading ../data/train.csv
# INFO:tensorflow:Step 9400 | Loss: 0.3409 | Spent: 45.1 secs | LR: 0.000490
# INFO:tensorflow:Step 9500 | Loss: 0.3341 | Spent: 11.6 secs | LR: 0.000475
# INFO:tensorflow:Step 9600 | Loss: 0.3649 | Spent: 11.3 secs | LR: 0.000460
# INFO:tensorflow:Step 9700 | Loss: 0.4285 | Spent: 11.5 secs | LR: 0.000445
# INFO:tensorflow:Step 9800 | Loss: 0.3838 | Spent: 11.5 secs | LR: 0.000430
# INFO:tensorflow:Step 9900 | Loss: 0.3979 | Spent: 11.3 secs | LR: 0.000415
# INFO:tensorflow:Step 10000 | Loss: 0.3407 | Spent: 11.4 secs | LR: 0.000400
# INFO:tensorflow:Step 10100 | Loss: 0.4650 | Spent: 11.5 secs | LR: 0.000385
# INFO:tensorflow:Step 10200 | Loss: 0.3506 | Spent: 11.4 secs | LR: 0.000370
# INFO:tensorflow:Step 10300 | Loss: 0.3820 | Spent: 11.4 secs | LR: 0.000355
# INFO:tensorflow:Step 10400 | Loss: 0.3903 | Spent: 11.3 secs | LR: 0.000340
# INFO:tensorflow:Step 10500 | Loss: 0.3306 | Spent: 11.3 secs | LR: 0.000325
# INFO:tensorflow:Step 10600 | Loss: 0.3872 | Spent: 11.1 secs | LR: 0.000310
# INFO:tensorflow:Step 10700 | Loss: 0.3512 | Spent: 11.3 secs | LR: 0.000295
# INFO:tensorflow:Step 10800 | Loss: 0.4411 | Spent: 11.3 secs | LR: 0.000280
# INFO:tensorflow:Step 10900 | Loss: 0.4510 | Spent: 11.2 secs | LR: 0.000265
# INFO:tensorflow:Step 11000 | Loss: 0.4201 | Spent: 11.5 secs | LR: 0.000250
# INFO:tensorflow:Step 11100 | Loss: 0.3729 | Spent: 11.1 secs | LR: 0.000235
# INFO:tensorflow:Step 11200 | Loss: 0.3018 | Spent: 11.0 secs | LR: 0.000220
# INFO:tensorflow:Step 11300 | Loss: 0.4297 | Spent: 11.2 secs | LR: 0.000205
# INFO:tensorflow:Step 11400 | Loss: 0.3808 | Spent: 11.1 secs | LR: 0.000190
# INFO:tensorflow:Step 11500 | Loss: 0.6064 | Spent: 11.0 secs | LR: 0.000175
# INFO:tensorflow:Step 11600 | Loss: 0.4570 | Spent: 11.3 secs | LR: 0.000160
# INFO:tensorflow:Step 11700 | Loss: 0.3446 | Spent: 11.3 secs | LR: 0.000145
# INFO:tensorflow:Step 11800 | Loss: 0.3162 | Spent: 11.2 secs | LR: 0.000130
# INFO:tensorflow:Step 11900 | Loss: 0.3402 | Spent: 11.3 secs | LR: 0.000115
# INFO:tensorflow:Step 12000 | Loss: 0.4246 | Spent: 11.0 secs | LR: 0.000100
# INFO:tensorflow:Step 12100 | Loss: 0.5089 | Spent: 11.2 secs | LR: 0.000115
# INFO:tensorflow:Step 12200 | Loss: 0.3422 | Spent: 11.1 secs | LR: 0.000130
# INFO:tensorflow:Step 12300 | Loss: 0.3938 | Spent: 11.1 secs | LR: 0.000145
# INFO:tensorflow:Step 12400 | Loss: 0.3629 | Spent: 11.2 secs | LR: 0.000160
# Reading ../data/test.csv
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.834
# INFO:tensorflow:Best Accuracy: 0.834
# Reading ../data/train.csv
# INFO:tensorflow:Step 12500 | Loss: 0.3882 | Spent: 45.0 secs | LR: 0.000175
# INFO:tensorflow:Step 12600 | Loss: 0.4145 | Spent: 11.3 secs | LR: 0.000190
# INFO:tensorflow:Step 12700 | Loss: 0.2807 | Spent: 11.2 secs | LR: 0.000205
